# %% [markdown]
# # <span style = "color:blue">Lab 1 Exercise</span>
# <div class = "alert alert-danger">
# Name your file after your student (matric) number, for example, A1234567B_Lab1Ex.ipynb
#
# Please let the lab facilitator check your work and mark your attendance before leaving the lab.
# </div>

# %% [markdown]
# ## <span style = "color:blue">Question 1</span>
#
# Type a favourite quote of yours into a Markdown cell (google for one if you have nothing in mind). Demonstrate the use of the following formatting functions:
#  - heading
#  - font styles (bold and italics)
#  - indentation
#  - hyperlink
#  - insertion of image

# %% [markdown]
# ## <span style = "color:red">Answer 1</span>
#
# > [**__“I think, therefore I am.”__** – _René Descartes_](https://philosophybreak.com/articles/i-think-therefore-i-am-descartes-cogito-ergo-sum-explained/)
#
# ![ReneDescartes.jpg](attachment:ReneDescartes.jpg)
# <!-- <img src="ReneDescartes.jfif" alt="ReneDescartes" width="200" height="400" title="ReneDescartes"> -->

# %% [markdown]
# ## <span style = "color:blue">Question 2</span>
#
# Render the following expressions using LaTeX:
# ![Lab1ExQ2.png](attachment:Lab1ExQ2.png)
#
# Hint: For rendering plus minus sign, use \pm

# %% [markdown]
# ## <span style = "color:red">Answer 2</span>
#
# $$\large a^2 + b^2 = c^2$$
# $$\large cot{\theta} = \pm{\sqrt{1-sin^2\theta}\over \sin\theta}$$
# $$\large x_{n+1} = rx_n(1-x_n)$$
# $$
# \large P(x,\sigma,\mu) = {1
#     \over{
#         \sigma\sqrt{
#             2\pi
#         }
#     }
# } e^{
#         {-(x-\mu)^2}/2\sigma^2
#     }
# $$
# $$\large y \approx \sqrt{
#     1+{
#         1\over{
#             \sqrt[3]{
#                 1+{
#                     1\over x
#                 }
#             }
#         }
#     }
# }$$
#
# $$ \large
# \sum^\infty_{i=0}{
#     {{(k+i)!}\over{k!i!}}
#     {x^i} = {
#         1\over{(1-x)^k}
#     }
# }
# $$
#
# $$ \large
# {df\over dt} = {
#     \lim\limits_{h \to 0} {
#         {f(t+h)-f(t)}\over
#         h
#     }
# }
# $$
#
# $$ \large
# {f(t) = }
# { 1\over {2\pi}}
# {
# \int_{-\infty}^{\infty} F(\omega)e^{-i\omega t} d\omega
# }
# $$
